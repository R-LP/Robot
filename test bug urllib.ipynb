# %%
import urllib
from urllib import request
#from matplotlib.finance import date2num

# %%
urlQuotes = urllib.request.urlopen('https://poloniex.com/public?command=returnChartData&currencyPair=BTC_XMR&start=1505664000&end=1505669000&period=14400')

# %%
urlQuotes.read()
# Out:
# b'[{"date":1505664000,"high":0.02602273,"low":0.02556253,"open":0.0260224,"close":0.02589998,"volume":119.63763304,"quoteVolume":4640.84940645,"weightedAverage":0.02577925}]'

# %%
urlTicker = urllib.request.urlopen('https://poloniex.com/public?command=returnTicker')

# %%
urlTicker.read()
# Out:
# b'{"BTC_BCN":{"id":7,"last":"0.00000033","lowestAsk":"0.00000034","highestBid":"0.00000033","percentChange":"-0.02941176","baseVolume":"42.19937674","quoteVolume":"122875082.64810875","isFrozen":"0","high24hr":"0.00000036","low24hr":"0.00000033"},"BTC_BELA":{"id":8,"last":"0.00002997","lowestAsk":"0.00002993","highestBid":"0.00002965","percentChange":"-0.00728718","baseVolume":"4.59514005","quoteVolume":"152227.71757361","isFrozen":"0","high24hr":"0.00003101","low24hr":"0.00002960"},"BTC_BLK":{"id":10,"last":"0.00005679","lowestAsk":"0.00005679","highestBid":"0.00005617","percentChange":"0.38681318","baseVolume":"445.50506448","quoteVolume":"7854222.83888954","isFrozen":"0","high24hr":"0.00006995","low24hr":"0.00004038"},"BTC_BTCD":{"id":12,"last":"0.02417953","lowestAsk":"0.02417568","highestBid":"0.02403008","percentChange":"-0.02502406","baseVolume":"18.81278495","quoteVolume":"755.71776509","isFrozen":"0","high24hr":"0.02572099","low24hr":"0.02400016"},"BTC_BTM":{"id":13,"last":"
# ...
